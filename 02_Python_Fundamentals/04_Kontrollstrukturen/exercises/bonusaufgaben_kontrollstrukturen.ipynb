# %% [markdown]
# # Übungen: Kontrollstrukturen & Schleifen
#
# Bearbeite die folgenden Aufgaben. Führe jede Zelle aus, um deine Lösung zu testen.

# %% [markdown]
# ### Aufgabe 1: Temperatur-Check
#
# Ergänze die fehlenden Vergleichsoperatoren und das fehlende Schlüsselwort, damit die Ausgabe korrekt funktioniert.
#
# Ergänze die fehlenden Teile (markiert mit `___`).

# %%
temperature = 25

if temperature ___ 30:
    print("Sehr heiß")
___ temperature ___ 20:
    print("Warm")
___:
    print("Kühl")

# %% [markdown]
# ### Aufgabe 2: Countdown mit while
#
# Ergänze die fehlenden Teile, sodass die Schleife von 5 bis 1 herunterzählt und danach `"Start!"` ausgibt.
#
# Ergänze die fehlenden Teile (markiert mit `___`).

# %%
count = ___

while count ___ 0:
    print(count)
    count ___ 1

print("Start!")

# %% [markdown]
# ### Aufgabe 3: Dictionary durchlaufen
#
# Ergänze die fehlenden Teile, sodass alle Schlüssel-Wert-Paare des Dictionarys ausgegeben werden.
#
# Ergänze die fehlenden Teile (markiert mit `___`).

# %%
person = {"name": "Alice", "age": 30, "city": "Berlin"}

for ___, ___ in person.___():
    print(f"{___}: {___}")

# %% [markdown]
# ### Aufgabe 4: Fehler finden
#
# Der folgende Code soll von 1 bis 5 zählen und dann `"Fertig"` ausgeben. Er enthält aber einen Fehler.
#
# Finde und korrigiere den Fehler.

# %%
# ⚠️ Dieser Code enthält einen Fehler
counter = 1

while counter <= 5:
    print(counter)
    counter += 2

print("Fertig")

# %% [markdown]
# ### Aufgabe 5: Was gibt dieser Code aus?
#
# Lies den folgenden Code sorgfältig. Was wird ausgegeben? Schreibe deine Antwort als Kommentar in die leere Zelle darunter, bevor du die Code-Zelle ausführst.

# %%
i = 0
while i < 6:
    if i == 4:
        break
    i += 1
else:
    print("Schleife normal beendet")

print(f"i = {i}")

# %%
# Meine Antwort:
#

# %% [markdown]
# ### Aufgabe 6: Gerade Zahlen mit range()
#
# Schreibe eine `for`-Schleife mit `range()`, die alle geraden Zahlen von 2 bis 20 (einschließlich) ausgibt.
#
# Hinweis: `range()` kann einen dritten Parameter (Schrittweite) annehmen.

# %%
# Deine Lösung hier:

# %% [markdown]
# ### Aufgabe 7: match/case erweitern
#
# Der folgende Code reagiert auf Tastatureingaben für ein Spiel. Erweitere den `match`-Block um zwei weitere Fälle:
#
# - `"q"` → gibt `"Spiel beendet"` aus
# - alle anderen Eingaben → gibt `"Unbekannte Taste"` aus

# %%
user_input = "q"

match user_input:
    case "w":
        print("Move up")
    case "a":
        print("Move left")
    case "s":
        print("Move down")
    case "d":
        print("Move right")
    # Füge hier die fehlenden Fälle hinzu:
