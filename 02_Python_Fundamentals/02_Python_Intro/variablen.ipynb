# %%
print("Variablen!")
# Out:
# Variablen!

# %%
my_variable = "Hello"  # snake case
# 2_another_var = 23

another_text = "World"

text_with_apostroph = "it's"

# %%
my_integer = 42

my_float = 4.2

# %%
my_bool = True
my_other_bool = False

# %%
# 12 // 3 # Ganzzahldivision, Integer division
12 / 3
# Out:
# 4.0

# %%
13 % 3
# Out:
# 1

# %%
3**3
# Out:
# 27

# %%
(4 * 3) + 6
# Out:
# 18

# %%
a = 14
b = 2.5

print(a + b)
print(a - b)

c = a * b

print(c)

a = 987
a = 0.14
a = "Hey"
print(a)
# Out:
# 16.5
# 11.5
# 35.0
# Hey

# %%
anzahl_snickers = 12
anzahl_snickers = anzahl_snickers - 1

print(anzahl_snickers)

anzahl_snickers -= 1
print(anzahl_snickers)

anzahl_snickers += 3
# anzahl_snickers *= 3
# anzahl_snickers //= 3
print(anzahl_snickers)
# Out:
# 11
# 10
# 3

# %%
10 >> 1

# 1010 -> 0101

10 << 1


10 & 1

#   1010
# & 0001
# ------
#   0000


10 | 1

#   1010
# | 0001
# ------
#   1011


10 ^ 2

#   1010
# ^ 0010
# ------
#   1000
# Out:
# 8

# %%
10 ^ 2
# Out:
# 8

# %%
3a = "13.0"

type(3a)
# Out:
#   Cell In[35], line 1
#     3a = "13.0"
#     ^
# SyntaxError: invalid decimal literal
