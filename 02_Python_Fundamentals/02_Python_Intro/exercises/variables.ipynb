# %%
# Step 1: Create variables:

# name = "Tomas"

# age = 28

# height = 1.75

name, age, height = "Michael", 40, 1.96

# %%
print("Hallo, mein Name ist ", name, " Ich bin ", age, " und bin ", height, "cm groß.")

print(f"Hallo, ich bin {name}, {age} alt und {height}m groß")
# Out:
# Hallo, mein Name ist  Michael  Ich bin  40  und bin  1.96 cm groß.
# Hallo, ich bin Michael, 40 alt und 1.96m groß

# %%
a = 13
b = "hallo"

a, b = b, a

print(a)
# Out:
# hallo

# %%
print(type(height))
print(type(name))
print(type(age))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>

# %%
# Step 2: Print the variables:

# %%
# Step 3: Check the type of the variables:

# %%
# Step 4: Casting

age_str = str(age)

print("My name is " + name + " and I am " + str(age_str) + " years old.")
# Out:
# My name is Michael and I am 40 years old.

# %%
print(str(4))
print(float(4))

print(int("4"))
print(int("1010", 2))
# print(int("hello"))

print(int(5.7))
# Out:
# 4
# 4.0
# 4
# 10
# 5

# %%
age = int(input("Wie alt bist du?: "))

age += 1

print(age)
print(type(age))
# Out:
# 40
# <class 'int'>
