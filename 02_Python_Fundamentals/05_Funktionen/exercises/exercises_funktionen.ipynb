# %% [markdown]
# # Übungen: Funktionen
#
# Bearbeite die folgenden Aufgaben. Führe jede Zelle aus, um deine Lösung zu testen.

# %% [markdown]
# ### Aufgabe 1: Funktion definieren und aufrufen
#
# Ergänze die fehlenden Teile (markiert mit `___`), sodass die Funktion `begruessung` den Text `Moin und Servus!` ausgibt, und rufe sie anschließend auf.

# %%
___ begruessung():
    print(___)


___()

# %% [markdown]
# ### Aufgabe 2: Parameter und f-String
#
# Ergänze die fehlenden Teile (markiert mit `___`), sodass die Funktion einen Namen als Parameter erhält und `Hallo, <Name>!` ausgibt.

# %%
def sag_hallo(___):
    print(f"Hallo, ___!")


sag_hallo("Fatima")
sag_hallo("Jonas")

# %% [markdown]
# ### Aufgabe 3: Rückgabewert
#
# Schreibe eine Funktion `quadrat(zahl)`, die das Quadrat der übergebenen Zahl **zurückgibt** (nicht nur ausgibt).
# Speichere das Ergebnis von `quadrat(7)` in einer Variable und gib sie aus.

# %% [markdown]
# ### Aufgabe 4: Fehler finden
#
# Der folgende Code enthält einen Fehler — finde und korrigiere ihn.
#
# > ⚠️ Dieser Code enthält einen Fehler

# %%
def ist_gerade(zahl):
    if zahl % 2 = 0:
        return "gerade"
    else:
        return "ungerade"


print(ist_gerade(4))
print(ist_gerade(7))

# %% [markdown]
# ### Aufgabe 5: Ausgabe vorhersagen
#
# Was gibt der folgende Code aus? Schreibe deine Antwort in die Markdown-Zelle darunter, **bevor** du den Code ausführst.
#
# **Was gibt dieser Code aus?**

# %%
def verdopple(n):
    return n * 2


def addiere(a, b):
    return a + b


ergebnis = addiere(verdopple(3), verdopple(4))
print(ergebnis)

# %%
# Antwort:
#

# %% [markdown]
# ### Aufgabe 6: Mehrere Rückgabewerte
#
# Ergänze die fehlenden Teile (markiert mit `___`), sodass die Funktion `min_und_max` das Minimum und das Maximum einer Liste zurückgibt. Entpacke die Rückgabewerte beim Aufruf direkt in zwei Variablen.

# %%
def min_und_max(zahlen):
    #
    return ___(zahlen), ___(zahlen)


___, ___ = min_und_max([4, 1, 9, 2, 7])

print(minimum)
print(maximum)

# %% [markdown]
# ### Aufgabe 7: Fehlerbehandlung mit try/except
#
# Schreibe eine Funktion `sicheres_teilen(a, b)`, die `a / b` berechnet und zurückgibt.
# Falls durch Null geteilt wird, soll die Funktion `"Division durch Null nicht erlaubt"` ausgeben und `None` zurückgeben.
#
# Teste die Funktion mit `sicheres_teilen(10, 2)` und `sicheres_teilen(5, 0)`.
